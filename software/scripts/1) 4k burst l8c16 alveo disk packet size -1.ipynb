# %%
import sqlite3
import math

# %%
dbCon = sqlite3.connect('dmaTest46_0buf_l8c16w64_Alveo_disk_packetMin1.db')

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run PrbsPlotter.py

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True, 
    collectionFilter = lambda rw: True,
    displayError = False,
    graphType = 'bar'
)

plt.rcParams['figure.figsize'] = [25, 25]
plt.title(f'Frame rate set to maximum')
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True, 
    collectionFilter = lambda rw: (rw[2]+1)%4 == 0 and math.log2(rw[0]).is_integer(),
    displayError = False,
    graphType = 'bar'
)

plt.rcParams['figure.figsize'] = [30, 25]
plt.title(f'Frame rate set to maximum')
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 3, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == 8 and rw[1] != 0,
    displayError = False)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == 8 and rw[1] != 0,
    displayError = False)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
for i in range(19):
    plotData(
        dbCon, 
        funcSelect = 1, 
        dataIndex = 4, 
        displayAggregate = False, 
        displayFilter = lambda val, maxi, index: index == i
    )
    
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
#       1 for i in range(19):
# ----> 2     plotData(
#       3         dbCon,
#       4         funcSelect = 1,
#       5         dataIndex = 4,
#       6         displayAggregate = False,
#       7         displayFilter = lambda val, maxi, index: index == i
#       8     )
#      10     plt.rcParams['figure.figsize'] = [20, 20]
#      11     plt.show()
#
# TypeError: plotData() got an unexpected keyword argument 'displayFilter'

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]>2**15 and not (rw[0]>5 or (rw[0]==5 and rw[1]==16)),
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False,
    legendLoc = 'upper left'
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(16,24,2.0))
plt.axhline(20000, linestyle = '-', color = 'k')
#plt.text(-2.8, 20000, "20Gbps")
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]>2**15 and (rw[0]>5 or (rw[0]==5 and rw[1]==16)),
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False,
    legendLoc = 'upper left'
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(16,24,2.0))
plt.axhline(20000, linestyle = '-', color = 'k')
#plt.text(-2.8, 20000, "20Gbps")
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]>2**15,
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False,
    legendLoc = 'upper left'
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(16,24,2.0))
plt.axhline(20000, linestyle = '-', color = 'k')
#plt.text(-2.8, 20000, "20Gbps")
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 4, 
    displayAggregate = True, 
    namer = lambda num: str(num[0]) + ", " + str(num[1]),
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False
)

plt.rcParams['figure.figsize'] = [20, 20]

plt.grid(True)
plt.xticks(np.arange(0,24,2.0))

plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: True,
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False,
    legendLoc = 'upper left'
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(0,24,2.0))
plt.axhline(20000, linestyle = '-', color = 'k')
plt.text(-2.8, 20000, "20Gbps")
plt.show()

# %%
for i in range(1,9):
    plotData(
        dbCon, 
        funcSelect = 2, 
        dataIndex = 3, 
        displayAggregate = True, 
        collectionFilter = lambda rw: rw[0] == i,
        namer = lambda num: str(num[0]) + ", " + str(num[1]), 
        legendTitle = '(Active Lanes, Active Channels)', 
        displayError = False,
        legendLoc = 'upper left'
    )
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(1,9):
    plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 3, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == i,
    legendTitle = f'frame size in words with {i} active lane(s)', 
    displayError = False
    )

    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(1,9):
    plotData(
        dbCon, 
        funcSelect = 2, 
        dataIndex = 4, 
        displayAggregate = True, 
        collectionFilter = lambda rw: rw[0] == i,
        namer = lambda num: str(num[0]) + ", " + str(num[1]), 
        legendTitle = '(Active Lanes, Active Channels)', 
        displayError = False,
        legendLoc = 'upper left'
    )
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(1,9):
    plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == i,
    legendTitle = f'frame size in words with {i} active lane(s)', 
    displayError = False
    )

    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
checked = {}
for i in range(1,9):
    for j in range(5):
        
        if i*2**j not in checked:
            checked[i*2**j] = True
            plotData(
            dbCon, 
            funcSelect = 1, 
            dataIndex = 4, 
            displayAggregate = True, 
            collectionFilter = lambda rw: rw[0]*rw[1]==i*2**j,
            displayError = False,
            graphType = 'bar'
            )


            plt.rcParams['figure.figsize'] = [25, 25]
            plt.title(f'Frame rate set to maximum')
            plt.show()

# %%
checked = {}
for i in range(1,9):
    for j in range(5):
        
        if i*2**j not in checked:
            checked[i*2**j] = True
            plotData(
            dbCon, 
            funcSelect = 1, 
            dataIndex = 3, 
            displayAggregate = True, 
            collectionFilter = lambda rw: rw[0]*rw[1]==i*2**j,
            displayError = False,
            graphType = 'bar'
            )


            plt.rcParams['figure.figsize'] = [25, 25]
            plt.title(f'Frame rate set to maximum')
            plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 3, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == 8 and rw[2] == 2048/2,
    displayError = False)

plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == 8 and rw[2] == 2048/2,
    displayError = False)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 5, 
    displayAggregate = False,
    collectionFilter = lambda rw: rw[0] == 8 and rw[2] == 2048/2,
    displayError = False)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
for i in range (1,9):
    plotData(
        dbCon, 
        funcSelect = 1, 
        dataIndex = 3, 
        displayAggregate = True,
        collectionFilter = lambda rw: rw[0] == i and rw[1] != 0,
        displayError = False)

    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()
