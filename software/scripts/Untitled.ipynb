# %%
import sqlite3
import math

# %%
dbCon1 = sqlite3.connect('dmaTest43_0buf_l8c16w64_Alveo.db')

# %%
dbCon2 = sqlite3.connect('dmaTest42_0buf_l8c16w64_Alveo_packetMin1.db')

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run PrbsPlotter.py

# %%
plotData(
    dbCon1, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]< 2**13 and rw[2]>2**3,
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False,
    legendLoc = 'upper left'
)
plotData(
    dbCon2, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]< 2**13 and rw[2]>2**3,
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = True,
    legendLoc = 'upper left'
)


name = []
for i in range(6):
    name.append(f'2^{i*2+3}')
    
plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(2,14,2.0), name)
plt.axhline(113000, linestyle = '-', color = 'k')
plt.text(1.5, 113000, "113Gbps")
plt.show()
