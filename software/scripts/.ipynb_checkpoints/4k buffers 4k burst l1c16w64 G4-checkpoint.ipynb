# %%
import sqlite3
import math

# %%
dbCon = sqlite3.connect('dmaTest15_4kbuf_l1c16w64_G4.db')

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run PrbsPlotter.py

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = False, 
    collectionFilter = lambda rw: rw[4] <= calculateExpectedRate(rw[3], rw[4]) and rw[9] == 0 and rw[10] == 0,
    displayFilter = lambda val, maxi, index: True, 
    displayError = False,
    graphType = 'bar'
)

plt.rcParams['figure.figsize'] = [25, 25]
plt.title(f'Frame rate set to maximum')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]%4 == 0 and math.log2(rw[0]).is_integer(),
    displayFilter = lambda val, maxi, index: True, 
    displayError = False,
    graphType = 'bar'
)

plt.rcParams['figure.figsize'] = [30, 25]
plt.title(f'Frame rate set to maximum')
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 3, 
    displayAggregate = False,
    collectionFilter = lambda rw: rw[0] == 1,
    displayFilter = lambda val, maxi, index: True, 
    displayError = True)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 plotData(
#       2     dbCon,
#       3     funcSelect = 1,
#       4     dataIndex = 3,
#       5     displayAggregate = False,
#       6     collectionFilter = lambda rw: rw[0] == 1,
#       7     displayFilter = lambda val, maxi, index: True,
#       8     displayError = True)
#      10 plt.rcParams['figure.figsize'] = [20, 20]
#      11 plt.show()
#
# File /afs/slac.stanford.edu/u/gu/sethk/pgp-pcie-apps/software/scripts/PrbsPlotter.py:239, in plotData(db_con, funcSelect, dataIndex, displayAggregate, collectionFilter, displayFilter, namer, legendTitle, displayError, graphType)
#     237 # collect and display data
#     238 if(funcSelect == 1):
# --> 239     collectDataVsVc(rows, dataIndex, collectionFilter, namer, displayFilter, displayAggregate, displayError, graphType)
# ...

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 3, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[0] == 1,
    displayFilter = lambda val, 
    maxi, 
    index: True
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
for i in range(19):
    plotData(
        dbCon, 
        funcSelect = 1, 
        dataIndex = 4, 
        displayAggregate = False, 
        displayFilter = lambda val, maxi, index: index == i
    )
    
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(19):
    plotData(
        dbCon, 
        funcSelect = 1, 
        dataIndex = 4, 
        displayAggregate = True, 
        displayFilter = lambda val, maxi, index: index == i
    )
    
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
#       1 for i in range(19):
# ----> 2     plotData(
#       3         dbCon,
#       4         funcSelect = 1,
#       5         dataIndex = 4,
#       6         displayAggregate = True,
#       7         displayFilter = lambda val, maxi, index: index == i
#       8     )
#      10     plt.rcParams['figure.figsize'] = [20, 20]
#      11     plt.show()
#
# File /afs/slac.stanford.edu/u/gu/sethk/pgp-pcie-apps/software/scripts/PrbsPlotter.py:239, in plotData(db_con, funcSelect, dataIndex, displayAggregate, collectionFilter, displayFilter, namer, legendTitle, displayError, graphType)
#     237 # collect and display data
#     238 if(funcSelect == 1):
# --> 239     collectDataVsVc(rows, dataIndex, collectionFilter, namer, displayFilter, displayAggregate, displayError, graphType)
# ...

# %%
for i in range(19):
    plotData(
        dbCon, 
        funcSelect = 1, 
        dataIndex = 3, 
        displayAggregate = False, 
        displayFilter = lambda val, maxi, index: index == i
    )
    
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
#       1 for i in range(19):
# ----> 2     plotData(
#       3         dbCon,
#       4         funcSelect = 1,
#       5         dataIndex = 3,
#       6         displayAggregate = False,
#       7         displayFilter = lambda val, maxi, index: index == i
#       8     )
#      10     plt.rcParams['figure.figsize'] = [20, 20]
#      11     plt.show()
#
# File /afs/slac.stanford.edu/u/gu/sethk/pgp-pcie-apps/software/scripts/PrbsPlotter.py:239, in plotData(db_con, funcSelect, dataIndex, displayAggregate, collectionFilter, displayFilter, namer, legendTitle, displayError, graphType)
#     237 # collect and display data
#     238 if(funcSelect == 1):
# --> 239     collectDataVsVc(rows, dataIndex, collectionFilter, namer, displayFilter, displayAggregate, displayError, graphType)
# ...

# %%
for i in range(19):
    plotData(
        dbCon, 
        funcSelect = 1, 
        dataIndex = 3, 
        displayAggregate = True, 
        displayFilter = lambda val, maxi, index: index == i
    )
    
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 for i in range(19):
# ----> 2     plotData(
#       3         dbCon,
#       4         funcSelect = 1,
#       5         dataIndex = 3,
#       6         displayAggregate = True,
#       7         displayFilter = lambda val, maxi, index: index == i
#       8     )
#      10     plt.rcParams['figure.figsize'] = [20, 20]
#      11     plt.show()
#
# File /afs/slac.stanford.edu/u/gu/sethk/pgp-pcie-apps/software/scripts/PrbsPlotter.py:239, in plotData(db_con, funcSelect, dataIndex, displayAggregate, collectionFilter, displayFilter, namer, legendTitle, displayError, graphType)
#     237 # collect and display data
#     238 if(funcSelect == 1):
# --> 239     collectDataVsVc(rows, dataIndex, collectionFilter, namer, displayFilter, displayAggregate, displayError, graphType)
# ...

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 4, 
    displayAggregate = True, 
    displayFilter = lambda val, maxi, index: True, 
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False
)

plt.rcParams['figure.figsize'] = [20, 20]

plt.grid(True)
plt.xticks(np.arange(1,20,2.0))

plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 5, 
    displayAggregate = False, 
    displayFilter = lambda val, maxi, index: True, 
    namer = lambda num: num, 
    legendTitle = 'Active Channels', 
    displayError = False
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    displayFilter = lambda val, maxi, index: True, 
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(1,20,2.0))

plt.show()

# %%
for i in range(5):
    plotData(
        dbCon, 
        funcSelect = 2, 
        dataIndex = 3, 
        displayAggregate = True, 
        displayFilter = lambda val, maxi, index: True,
        collectionFilter = lambda rw: rw[1] == 2**i,
        namer = lambda num: str(num[0]) + ", " + str(num[1]), 
        legendTitle = '(Active Lanes, Active Channels)', 
        displayError = False
    )

    plt.rcParams['figure.figsize'] = [20, 20]
    plt.grid(True)
    plt.xticks(np.arange(1,20,2.0))

    plt.show()
