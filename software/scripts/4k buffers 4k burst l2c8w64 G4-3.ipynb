# %%
import sqlite3
import math

# %%
dbCon = sqlite3.connect('dmaTest17_4kbuf_l2c8w64_G4.db')

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# %run PrbsPlotter.py

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = False, 
    collectionFilter = lambda rw: rw[4] <= calculateExpectedRate(rw[3], rw[4]) and rw[9] == 0 and rw[10] == 0,
    displayFilter = lambda val, maxi, index: True, 
    displayError = False,
    graphType = 'bar'
)

plt.rcParams['figure.figsize'] = [25, 25]
plt.title(f'Frame rate set to maximum')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 plotData(
#       2     dbCon,
#       3     funcSelect = 1,
#       4     dataIndex = 4,
#       5     displayAggregate = False,
#       6     collectionFilter = lambda rw: rw[4] <= calculateExpectedRate(rw[3], rw[4]) and rw[9] == 0 and rw[10] == 0,
#       7     displayFilter = lambda val, maxi, index: True,
#       8     displayError = False,
#       9     graphType = 'bar'
#      10 )
#      12 plt.rcParams['figure.figsize'] = [25, 25]
#      13 plt.title(f'Frame rate set to maximum')
#
# TypeError: plotData() got an unexpected keyword argument 'displayFilter'

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True, 
    collectionFilter = lambda rw: rw[2]%4 == 0 and math.log2(rw[0]).is_integer(),
    displayError = False,
    graphType = 'bar'
)

plt.rcParams['figure.figsize'] = [30, 25]
plt.title(f'Frame rate set to maximum')
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == 2 and rw[1] != 0,
    displayError = False)

plt.rcParams['figure.figsize'] = [20, 20]
plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 4, 
    displayAggregate = True, 
    displayFilter = lambda val, maxi, index: True, 
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False
)

plt.rcParams['figure.figsize'] = [20, 20]

plt.grid(True)
plt.xticks(np.arange(1,20,2.0))

plt.show()

# %%
plotData(
    dbCon, 
    funcSelect = 2, 
    dataIndex = 3, 
    displayAggregate = True, 
    namer = lambda num: str(num[0]) + ", " + str(num[1]), 
    legendTitle = '(Active Lanes, Active Channels)', 
    displayError = False
)

plt.rcParams['figure.figsize'] = [20, 20]
plt.grid(True)
plt.xticks(np.arange(1,20,2.0))

plt.show()

# %%
for i in range(1,3):
    plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 3, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == i,
    legendTitle = f'frame size in words with {i} active lane(s)', 
    displayError = False
    )

    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(1,3):
    plotData(
        dbCon, 
        funcSelect = 2, 
        dataIndex = 3, 
        displayAggregate = True, 
        collectionFilter = lambda rw: rw[0] == i,
        namer = lambda num: str(num[0]) + ", " + str(num[1]), 
        legendTitle = '(Active Lanes, Active Channels)', 
        displayError = False,
        legendLoc = 'upper left'
    )
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(1,3):
    plotData(
    dbCon, 
    funcSelect = 1, 
    dataIndex = 4, 
    displayAggregate = True,
    collectionFilter = lambda rw: rw[0] == i,
    legendTitle = f'frame size in words with {i} active lane(s)', 
    displayError = False
    )

    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
for i in range(1,3):
    plotData(
        dbCon, 
        funcSelect = 2, 
        dataIndex = 4, 
        displayAggregate = True, 
        collectionFilter = lambda rw: rw[0] == i,
        namer = lambda num: str(num[0]) + ", " + str(num[1]), 
        legendTitle = '(Active Lanes, Active Channels)', 
        displayError = False,
        legendLoc = 'upper left'
    )
    plt.rcParams['figure.figsize'] = [20, 20]
    plt.show()

# %%
checked = {}
for i in range(1,3):
    for j in range(3):
        
        if i*2**j not in checked:
            checked[i*2**j] = True
            plotData(
            dbCon, 
            funcSelect = 1, 
            dataIndex = 4, 
            displayAggregate = True, 
            collectionFilter = lambda rw: rw[0]*rw[1]==i*2**j,
            displayError = False,
            graphType = 'bar'
            )


            plt.rcParams['figure.figsize'] = [25, 25]
            plt.title(f'Frame rate set to maximum')
            plt.show()

# %%
checked = {}
for i in range(1,3):
    for j in range(3):
        
        if i*2**j not in checked:
            checked[i*2**j] = True
            plotData(
            dbCon, 
            funcSelect = 1, 
            dataIndex = 3, 
            displayAggregate = True, 
            collectionFilter = lambda rw: rw[0]*rw[1]==i*2**j,
            displayError = False,
            graphType = 'bar'
            )


            plt.rcParams['figure.figsize'] = [25, 25]
            plt.title(f'Frame rate set to maximum')
            plt.show()
